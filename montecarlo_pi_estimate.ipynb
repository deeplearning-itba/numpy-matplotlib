# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from montecarlo_utils import estimate_pi, plot_problem
import montecarlo_utils as mu

# %% [markdown]
# ## Planteo del problema de estimación de $\pi$ por Monte Carlo

# %%
mu.plot_problem(1000)

# %%
N = 100_000
_, pi_estimated = mu.estimate_pi(N)

print(f'La estimación de pi con {N} observacionoes es {pi_estimated}')
# Out:
# La estimación de pi con 100000 observacionoes es 3.1486
