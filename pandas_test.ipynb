# %%
import pandas as pd

# %%
df = pd.read_parquet('data/ch_Nota_2024-04-01T00:00:00_2024-04-02T00:00:00_len_3699.parquet')

# %%
df.columns
# Out:
# Index(['Old Id', 'Airing Landing', 'Airing Thumb', 'Order', 'External Code',
#        'Start Date Utc', 'End Date Utc', 'Start Date Local', 'End Date Local',
#        'Start Time Utc', 'End Time Utc', 'Start Time Local', 'End Time Local',
#        'Asset Id', 'Asset Name', 'Asset Landing', 'Asset Thumb', 'Asset Clip',
#        'Author Id', 'Author Name', 'Keyword Id', 'Keyword Name', 'Entity Id',
#        'Entity Name', 'Entity Thumb', 'Media Group Id', 'Media Group Name',
#        'Impact', 'Interval Start', 'Interval End'],
#       dtype='object')

# %%
df_indexed = df[['Asset Id', 'Asset Name', 'Author Name', 'Entity Name', 'Keyword Name', 'Start Date Local', 'Start Time Local']].set_index('Asset Id')

# %%
df_entidades = pd.read_parquet('data/bq_entities_Nota_2024-04-01T00:00:00_2024-04-03T00:00:00_18910.parquet').set_index('in__ms_id')

# %%
df_entidades
# Out:
#                                                    in__title  \
# in__ms_id
# 105604687  Una Ciudad abandonada, un Barrio inseguro: Vue...
# 105604699  Fallece Cleotilde Yamashita, fundadora del Oas...
# 105604714  ¿El INAI va a desaparecer? Esta es la propuest...
# 105604752  Semana clave para el Gobierno: apuesta a avanz...
# 105604748  Boca: se conoció la suspensión a Fabra por la ...
# ...                                                      ...
# 105584160    México, descolocado en el hemisferio occidental
# 105583600  ¿Decisiones de Daniel Noboa para impulsar la m...
# 105583793  MasterChef Celebrity México 2024: ¿Quién sale ...
# 105584086        Cierra Pa'l Norte con una explosión de rock
# 105584735  Video viral del Metro CDMX: Usuarios defienden...
#
#                                                     in__text  \
# in__ms_id
# 105604687  Publicado en Por Tras 16 años de gobierno hege...
# 105604699  Los Mochis, Sin.- A través de la red social Fa...
# ...

# %%
len(df_entidades), len(df_indexed)
# Out:
# (18910, 3699)

# %%
df_indexed.join(df_entidades, how='inner')
# Out:
#                                                   Asset Name  \
# Asset Id
# 105628101  Elecciones en Venezuela: María Corina Machado ...
# 105628367  El populismo derivó en que los argentinos fina...
# 105629611  Día de los veteranos de Malvinas: el impacto y...
# 105629617  La revolución del efectivo: la Generación Z re...
# 105628730  El galante gesto de Diego Maradona con Mariana...
# ...                                                      ...
# 105641179  Cuánto cuesta ver a la Selección Argentina en ...
# 105593608  Javier Milei contra Estela de Carlotto: ``Pidi...
# 105580130  Comercios en Córdoba: cayó 20.9% las ventas po...
# 105640664  Milei homenajeó a los héroes de Malvinas y con...
# 105580630  Subtes: reabrió la estación Facultad de Medici...
#
#                                Author Name  \
# Asset Id
# 105628101                          Infobae
# 105628367                          Infobae
# 105629611                          Infobae
# ...

# %%
df[['Asset Id', 'Author Name']].to_dict(orient='records')
# Out:
# [{'Asset Id': 105628101, 'Author Name': 'Infobae'},
#  {'Asset Id': 105628367, 'Author Name': 'Infobae'},
#  {'Asset Id': 105665266, 'Author Name': 'Infobae'},
#  {'Asset Id': 105629611, 'Author Name': 'Infobae'},
#  {'Asset Id': 105665814, 'Author Name': 'Infobae'},
#  {'Asset Id': 105629617, 'Author Name': 'Infobae'},
#  {'Asset Id': 105628730, 'Author Name': 'Infobae'},
#  {'Asset Id': 105666818, 'Author Name': 'Infobae'},
#  {'Asset Id': 105638384, 'Author Name': 'Infobae'},
#  {'Asset Id': 105628418, 'Author Name': 'Infobae'},
#  {'Asset Id': 105641111, 'Author Name': 'Infobae'},
#  {'Asset Id': 105665796, 'Author Name': 'Infobae'},
#  {'Asset Id': 105664697, 'Author Name': 'Infobae'},
#  {'Asset Id': 105666138, 'Author Name': 'Infobae'},
#  {'Asset Id': 105665787, 'Author Name': 'Infobae'},
#  {'Asset Id': 105638558, 'Author Name': 'Infobae'},
#  {'Asset Id': 105638367, 'Author Name': 'Infobae'},
#  {'Asset Id': 105665312, 'Author Name': 'Infobae'},
# ...

# %%
#df_indexed.to_dict(orient='records')

# %%
df['Author Name'].unique()
# Out:
# array(['Infobae', 'La Gaceta Diario', 'MDZ Online', 'Diario Panorama',
#        'Diario Río Negro', 'Perfil', 'Ambito Financiero', 'Magazine',
#        'Jornada Online', 'C5N', 'El Tribuno', 'Teledoce', 'TyC Sports',
#        'La Mañana Neuquén', 'Cadena 3 Argentina', 'Clarín',
#        'Minuto Uno - Televisión On line', 'La Voz', 'Página/12',
#        'La Nación', 'El Destape', 'Rosario3.com', 'Parlamentario',
#        'La Brújula 24', 'Filo.news', 'Data Clave', 'Café x Medio',
#        'Noticias Argentinas', 'TN Todo Noticias', 'Diario Los Andes',
#        'Diario Crónica', 'Olé', 'La Nueva', 'Diario Tiempo Sur',
#        'De La Bahía', 'Diario Popular', 'Diario El Litoral',
#        'La Nueva Mañana', 'Diario UNO', 'Tiempo Argentino',
#        'Big Bang News', 'Diario La Capital', 'Real Politik',
#        'i Profesional', 'Wips Digital', 'La Nueva Prensa',
#        'Primero Bahía', 'Letra P', 'A24', 'Diario El Día', 'Vía País',
# ...

# %%
df['Author Name'].value_counts()
# Out:
# Author Name
# Infobae                 315
# Clarín                  205
# La Nación               177
# MDZ Online              174
# El Tribuno              171
#                        ...
# Café x Medio              5
# Posturas Jorge Rubio      5
# Comercio y Justicia       3
# Infonegocios              2
# Panorama Directo          1
# Name: count, Length: 65, dtype: int64

# %%
# Competencia de Kaggle

# %%
df_kaggle = pd.read_csv('data/application_test.csv')

# %%
print(list(df_kaggle.columns))
# Out:
# ['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_A
# ...
